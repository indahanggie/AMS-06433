# %% [markdown]
#     ## Nama  : Indah Anggie Ashari
#     ## Nim   : A12.2020.06433
#     ## Kelpk : A12.6501

# %% [markdown]
# # Eksperimen dan Pengumpulan Dataset

# %% [markdown]
#    ## Pemanggilan Library 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("o5PcOUg4q7e4R6SwpkbUwAPtL", "mrovKXD6FIQIIT6bLxkIpfqnqQ5oIpqz0yVZjuuuJW3fGZfneZ")
    auth.set_access_token("1569929584673701889-izjVasL6NUXfwzNPK4bsJHV742fgJy", "ed8ALXe514aIHjG7ThNr0ZNH09Lyxv2u4BbGJ7vr1U6Tw")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# buat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# # Ambil Tweet dari Username

# %% [markdown]
# ## Username yang saya gunakan yaitu @psisfcofficial

# %%
tweets = extractor.user_timeline(screen_name="psisfcofficial", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 100 tweet teratas:
#
# Selamat dan sukses atas dilantiknya Bapak @hendrarprihadi sebagai kepala LKPP. Terimakasih atas dedikasi Bapak Hend… https://t.co/sO4997T4Xf
#
# Di sini Semarang, Di sana Malang. Di mana-mana kita saudara💙
#
# Tak berhenti kami bersimpati dan kirim semangat moral… https://t.co/OtG1W8aTNm
#
# 🚨Informasi terkait tiket PSIS vs Bhayangkara FC
#
# Silakan baca ketentuan di atas dan diperhatikan mekanisme serta ta… https://t.co/C1H75TwMBo
#
# 🔵 Team News
#
# 📰 https://t.co/Z8hmhMglXZ
#
# #PSIS https://t.co/CWwK83vrVA
#
# #SalingSupport 🎗️ https://t.co/HJesn2iFby
#
# "Kami Arema, Salam Satu Jiwa" 🌟
#
# Cuplikan video kami dari Semarang malam lalu untuk mengirim doa dan semangat bagi… https://t.co/XM5dlAW5Qp
#
# Duka kita bersama, tapi percayalah harus bangkit. Ini doa kami untuk insiden di Stadion Kanjuruhan malam lalu🙏🏼🥀… https://t.co/Lv6Pv7yFIY
#
# Laga PSIS Semarang vs Bhayangkara FC ditunda.
#
# #PSIS
#
# https://t.co/GK6XppASRR
#
# Keluarga besar PSIS Semarang turut berdukacita dalam insiden yang terjadi di Stadion Kanjuruhan. Sejenak kita kirim… https://t.co/uEx1NgyYLu
#
# Persiapan matang selama 2 minggu jadi modal PSIS Semarang untuk siap raih kemenangan di laga esok hari kontra Bhaya… https://t.co/L2sFhmPwtZ
#
# Perjuangan berlanjut!
#
# Hadapi Bhayangkara FC, PSIS siap berjuang untuk raih 3 poin. Pantang menyerah, yoh iso yoh!… https://t.co/zTPztU1LAS
#
# Kami kembali ke Jatidiri untuk raih poin penuh. Ayo Semarang‼️🔵
#
# #PSIS | #Matchday https://t.co/r0vN0SaRRJ
#
# PSIS resmikan training ground ketiga,
#
# https://t.co/muBGVUSNur
#
# Setelah Stadion Citarum dan Lapangan Mardi Soenarto, inilah training ground terbaru kami yang hari ini di resmikan… https://t.co/OAeWktghgX
#
# Berdasarkan surat resmi dari PT. LIB, terdapat perubahan waktu kick off saat PSIS Semarang menjamu Bhayangkara FC d… https://t.co/bh8Kd0ZyJw
#
# 𝐇𝐞 𝐢𝐬 𝐛𝐚𝐜𝐤. 👁️🔵
#
# #PSIS https://t.co/8AzkHeumnX
#
# 🎟Tiket offline via ticket box tersedia lur!
#
# Silakan menuju lokasi ticket box di postingan ini untuk mendapatkan t… https://t.co/dAvA1rjFbk
#
# Cara pemesanan tersedia di slide berikutnya ya dulur. Tiket online via tiketcom tersedia barat dan timur, sedangkan… https://t.co/XzWjdPeEk3
#
# 🎟Tiket PSIS Semarang vs Persikabo 1973 tersedia! Dapatkan tiketnya sekarang🙌🏼 https://t.co/Q2zcbMbGvV
#
# 🔵TEAM NEWS🔵
#
# PSIS Semarang daftarkan Ian Andrew Gillan sebagai Pelatih Kepala sementara. Welcome back Coach Ian And… https://t.co/EsG4WgvcoW
#
# Selamat hari Senin, Blues! 🔵
#
# #PSIS https://t.co/9aXATCznkh
#
# 👑 is back
#
# #PSIS https://t.co/1tdudYxccQ
#
# Physical training ++ 💪🏼
#
# #PSIS https://t.co/1TyHPLbmoX
#
# Mulai bersiap kembali hari ini. 💪🏼💥
#
# #PSIS https://t.co/GdoHAC6nAM
#
# 🔵Team News🔵
#
# https://t.co/kIMxNtZcem
#
# #PSIS
#
# Hari yang berat di Tangerang. 😞
#
# #PSIS | #TGRSMG https://t.co/J72DbWB6Zu
#
# '80 Akurat namun mampu diamankan, tendangan keras dari luar kotak penalty dari Taufik Hidayat.
#
# #PSIS | #TGRSMG
#
# '77 Through pass Ofan kepada Bahril deras tapi bola masih dapat diamankan kiper Persita.
#
# #PSIS | #TGRSMG
#
# '72 Pergantian pemain:
#
# ⬆️ Bahril Fahreza
# ⬇️ Reza Irfana
#
# #PSIS | #TGRSMG
#
# '65 Pergantian pemain:
#
# ⬆️ Taufik Hidayat
# ⬇️ Frendi Saputra
#
# #PSIS | #TGRSMG
#
# Gol Persita 1-0. 😓
#
# #PSISDAY | #TGRSMG
#
# '62 Hampir Riyannnn!! Build up serangan dari Dewa-Taisei diakhiri dengan sontekan yang mampu diamankan kiper Persita.
#
# #PSISDAY | #TGRSMG
#
# Second half underway! ⚡️⚽️⚽️
#
# #PSISDAY | #TGRSMG
#
# Setengah main.
#
# #PSISDAY | #TGRSMG https://t.co/VRXpdgdL8M
#
# Tambahan waktu 1 menit.
#
# #PSISDAY | #TGRSMG
#
# '43 Aqsha!!!! Hampir saja memecah kebuntuan, sayang tendangan keras Aqsha terlalu melebar dari kiper.
#
# #PSISDAY | #TGRSMG
#
# '35 Umpan crossing Ofan masih terlalu dalam belum mampu disambut oleh Taisei.
#
# #PSISDAY | #TGRSMG
#
# '33 Visi Fredyan Ucil lihat pergerakan Taisei dengan through pass, sayang masih diamankan kiper Persita.
#
# #PSISDAY | #TGRSMG
#
# '13 Bola tendangan pojok Riyan memaksa kiper Persita keluar, sayang bola rebound ditendang Dewa terlalu lemah.
#
# #PSISDAY | #TGRSMG
#
# Tribute untuk ayahanda mas Hari Nur, stay strong Mas Hari Nur🙏🏼💙
#
# #PSISDAY | #TGRSMG https://t.co/8QjbM68vy5
#
# Kita mulai perjuangan poin penuh hari ini, kick-off babak pertama📢
#
# 🟣Persita Tangerang 🆚 PSIS Semarang⚪️
#
# #PSISDAY
#
# Tidak pernah berhenti berkata untuk selalu fokus demi kemenangan. Kita bisa Semarang, Yoh iso yoh‼️⚡🔵
#
# #PSISDAY |… https://t.co/wlYwKTF5tc
#
# 𝑶𝑵 𝑫𝑼𝑻𝒀 𝑻𝑶𝑫𝑨𝒀⚔️
#
# XI: Redondo (GK), Ucil, Dewa, Alie, Frendi©️, Aqsha, Reza, Guntur, Riyan, Ofan, Taisei
#
# Subs: Yofa… https://t.co/NcEjX3aNXF
#
# Optimis poin tiga, yakin bisa Semarang⚡️
#
# #PSISDAY https://t.co/tqsHoAz7RS
#
# Gedor benteng tebal itu, kita bisa Semarang⚡️🔵
#
# YOH ISO YOH‼️
#
# #PSISDAY https://t.co/ke0pdgpRq3
#
# Rayakan hari PSIS sedunia‼️
# Poin penuh kita bawa pulang, c'mon Laskar Mahesa Jenar🔵🔵🔵
#
# #PSISDAY https://t.co/EtVucBd61H
#
# Siap lanjutkan tren positif! Bermodal kemenangan di laga sebelumnya, PSIS incar kemenangan di laga tandang menghada… https://t.co/Tb4qLrYd7r
#
# Turut berduka cita mas @harinuryulianto 🙏🏼🥀 https://t.co/UxJ23sgyDE
#
# Kembali berjuang esok hari,
# ⚽️Persita Tangerang vs PSIS Semarang
#
# 𝒀𝑶𝑯 𝑰𝑺𝑶 𝒀𝑶𝑯💪🏼🔵
#
# #PSIS | #Matchday https://t.co/VTNvO0Q1hE
#
# Our Blues in XI GW 9 🔵🔥
# 1️⃣4️⃣🤝4️⃣6️⃣ https://t.co/tT6kxTYdNq https://t.co/GAeci6I6Dr
#
# @ForzaPSIS 😂😂
#
# Kami berangkat pagi ini ke Tangerang. Bismillah! 😇
#
# #PSIS https://t.co/ZYARjHoW93
#
# Travel squad to Tangerang✈️
# Jemput poin penuh, bawa pulang lagi ke Semarang. Yoh iso yoh!
#
# #PSIS https://t.co/z7Y1KZOk3n
#
# Seberapa PSIS sih Andreas Ado? 🤔
#
# Kami challenge Andreas di "Seberapa PSIS kamu?" supported by Pop Mie, simak selen… https://t.co/BIKF1Piab9
#
# Sudahi euforia, alih fokus ke pertandingan selanjutnya🔜💪🏼
#
# #PSIS https://t.co/jhMTPyq1LB
#
# 𝐎𝐔𝐑 𝐇𝐀𝐓𝐓𝐑𝐈𝐂𝐊 𝐇𝐄𝐑𝐎⚽️⚽️⚽️ @RiyanArdi_02
#
# #PSIS https://t.co/EQh3JHS5be
#
# Selamat pagi! 💙 https://t.co/heTtCm6VcP
#
# RT @gunturtriaji: 🦾🦾💙💙🫡🫡 #YohIsoYoh @psisfcofficial https://t.co/reJJ9wk9S4
#
# Kebersamaan yang tidak pernah usai, terimakasih telah berjuang bersama @PanserBiruTweet @Snex2005 💙
#
# #PSISDAY https://t.co/Im4Lk63Bx7
#
# YES BLUES!! 🔵🔵🔵⚡️
#
# #PSIS https://t.co/LDYqOwwNVg
#
# Gol Persikabo, 3-2 🙄
#
# #PSISDAY
#
# Pergantian pemain:
#
# ⬆️ Damas, Delfin
# ⬇️ Guntur, Aqsha
#
# #PSISDAY
#
# '83 Rachmat Hidayat.... memilih untuk menyikat bola padahal posisi Taisei kosong. Bola clearance dari bek Persikabo.
#
# #PSISDAY
#
# Pergantian pemain:
#
# ⬆️ Rachmad
# ⬇️ Wawan
#
# #PSISDAY
#
# '70 MEH WE!! Taisei otak atik bola di pertahanan Persikabo, sayang sodorannya masih melebar dari gawang Persikabo.
#
# #PSISDAY
#
# Sodoran Ucil dari sisi kanan mampu memecah pertahanan Persikabo, bola dari Ucil berbelok arah terkena Riyan untuk c… https://t.co/hEb43aJFlz
#
# HATTRICK DARI RIYAN ARDIYANSYAH!!! ⚽️⚽️⚽️
#
# 🔵3-1⚔️
#
# #PSISDAY
#
# '51 Tendangan Riyan masih terlalu tinggi dari gawang Persikabo.
#
# #PSISDAY
#
# Second half underway! ⚽️⚽️
#
# #PSISDAY
#
# Setengah main! 💥 https://t.co/ST343UMSSV
#
# Tambahan waktu 2 menit babak pertama.
#
# #PSISDAY
#
# '41 Gol Persikabo 2-1.
#
# #PSISDAY
#
# '25 Tendangan Ucil dari sisi kanan gawang Persikabo mampu dimentahkan, tipis dari gawang.
#
# #PSISDAY
#
# Dalam situasi serangan balik, Taisei kirim umpan akurat kepada Riyan yang bebas. Gol kedua dari Riyan Ardiyansyah!! ⚽️⚽️
#
# #PSISDAY
#
# RIYAN TO THE BRACEEEE!!!! 2-0 ⚽️⚽️
#
# #PSISDAY
#
# Menyambut umpan cut back Wawan, Ucil kirim umpan kepada Riyan di tiang dekat, tanpa ragu langsung menceploskan bola… https://t.co/IKgwUxhGp1
#
# GOL RIYAN ARDIYANSYAHHHH!!! 1-0 PSIS MEMIMPIN!!
#
# #PSISDAY
#
# It's time, kick-off babak pertama!
#
# 🔵🆚⚔️
#
# #PSISDAY
#
# Panaskan mesinnya, bersiap berjuang hari ini! 💪🏼⚡️
#
# #PSISDAY https://t.co/szD2E4Mzei
#
# 🔵Team News
#
# IX: Redondo (GK), Fred Ucil, Dewa, Alie, Frendi©, Aqsha, Guntur, Jonathan, Riyan, Wawan, Taisei
#
# Subs:… https://t.co/GwbNjBvFp9
#
# Home. 🏟
#
# #PSISDAY https://t.co/p6QjzfQpFQ
#
# 𝗨𝗡𝗟𝗘𝗔𝗦𝗛 𝗧𝗛𝗘 𝗠𝗔𝗫𝗜𝗠𝗨𝗠 𝗣𝗢𝗪𝗘𝗥‼️
#
# #PSISDAY https://t.co/p2VrDVKFbY
#
# Kembali berlaga di kandang, maksimalkan perjuangan untuk kembali menang! Hadapi Persikabo, PSIS menang 1-0 pada due… https://t.co/OssO20d1uU
#
# Kembali ke rumah untuk berjuang demi poin penuh. Jangan biarkan mereka ambil, pasti kita menang, Laskar Mahesa Jena… https://t.co/eUhgc3XfIE
#
# Selamat pagi! 🙌🏼
# Fokus kami ke laga vs Persikabo🔜
#
# #PSIS https://t.co/MgkcYr5yJX
#
# Alfeandra Dewangga catat nama di Best XI Pekan ke-8 BRI Liga 1 2022/23 sekigus dinobatkan menjadi Best Young Player… https://t.co/Fu7d4lMjx2
#
# 🎟Tiket offline via ticket box tersedia lur!
#
# Silakan menuju lokasi ticket box di bawah ini untuk dapatkan tiket pe… https://t.co/fGnO9BBgcK
#
# 🎟Tiket PSIS Semarang vs Persikabo 1973 tersedia! Tiket online via tiketcom tersedia barat dan timur, tiket utara da… https://t.co/osfnSXtpnD
#
# 🎬Dibalik layar perjuangan PSIS Semarang di Stadion Manahan kontra Persis Solo
#
# ✅Tonton selengkapnya di sini… https://t.co/d4H06O2TG8
#
# Aqsha Saniskara jalankan peran baru sebagai gelandang bertahan dalam laga lawan Persis Solo di matchday lalu. Terus… https://t.co/v8RJdfhmZl
#
# 📸 Potret laga lalu, Persis vs PSIS
#
# #PSIS https://t.co/SzYs0QypLF
#
# Terimakasih Panser Biru dan Snex yang ikut berjuang pada laga hari ini. Hati-hati di jalan, selamat sampai tujuan.… https://t.co/AQ8u66PU6I
#
# Full time: 0️⃣ - 0️⃣ https://t.co/XT7kHbah7T
#
# @Paman43405620 admin e gak main soale mas
#
# Pergantian pemain:
#
# ⬆️ Hari Nur
# ⬇️ Wawan
#
# #PSISDAY
#
# 😤😤😤😤
#
# '73 Tendangan spekulasi Jonathan masih melebar.
#
# #PSISDAY
#
# Pergantian pemain:
#
# ⬆️ Delfin
# ⬇️ Riyan
#
# #PSISDAY
#
# '64 Taisei hampir membuka keunggulan, sayang tendangannya masih dihalau Riyandi.
#
# #PSISDAY
#
# Pergantian pemain:
# ⬆️ Andreas
# ⬇️ Ofan
#
# #PSISDAY

# %% [markdown]
# ## Memasukkan ke dataframe pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   Selamat dan sukses atas dilantiknya Bapak @hen...
# 1   Di sini Semarang, Di sana Malang. Di mana-mana...
# 2   🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3   🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 4           #SalingSupport 🎗️ https://t.co/HJesn2iFby
# ..                                                ...
# 95                                               😤😤😤😤
# 96  '73 Tendangan spekulasi Jonathan masih melebar...
# 97  Pergantian pemain:\n\n⬆️ Delfin\n⬇️ Riyan\n\n#...
# 98  '64 Taisei hampir membuka keunggulan, sayang t...
# 99  Pergantian pemain:\n⬆️ Andreas\n⬇️ Ofan\n\n#PS...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_psisfcofficial.csv')

# %% [markdown]
# ## Cleaning Word
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_psisfcofficial.csv')
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  Selamat dan sukses atas dilantiknya Bapak @hen...
# 1           1  Di sini Semarang, Di sana Malang. Di mana-mana...
# 2           2  🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3           3  🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 4           4          #SalingSupport 🎗️ https://t.co/HJesn2iFby
# 5           5  "Kami Arema, Salam Satu Jiwa" 🌟\n\nCuplikan vi...
# 6           6  Duka kita bersama, tapi percayalah harus bangk...
# 7           7  Laga PSIS Semarang vs Bhayangkara FC ditunda. ...
# 8           8  Keluarga besar PSIS Semarang turut berdukacita...
# 9           9  Persiapan matang selama 2 minggu jadi modal PS...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  Selamat dan sukses atas dilantiknya Bapak @hen...
# 1             1  Di sini Semarang, Di sana Malang. Di mana-mana...
# 2             2  🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3             3  🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 4             4          #SalingSupport 🎗️ https://t.co/HJesn2iFby
# ..          ...                                                ...
# 195         195  GOLAZO FROM JONATHAN CANTILLANA ZORRILLAAAA!!!...
# 196         196                 Gol untuk Persik 1-1. \n\n#PSISDAY
# 197         197  '54 Krusial! Penyelamatan Redondo hentikan usa...
# 198         198  Pergantian pemain\n\nWawan masuk,\nHari Nur ke...
# 199         199  Kick-off babak kedua! Tambah atau pertahankan....
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# # Preprocessing Dataset
# #### Yang harus dilakukan yaitu instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Requirement already satisfied: ekphrasis in c:\anaconda\lib\site-packages (0.5.4)
# Requirement already satisfied: termcolor in c:\anaconda\lib\site-packages (from ekphrasis) (2.0.1)
# Requirement already satisfied: matplotlib in c:\anaconda\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: ftfy in c:\anaconda\lib\site-packages (from ekphrasis) (6.1.1)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: ujson in c:\anaconda\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: nltk in c:\anaconda\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: tqdm in c:\anaconda\lib\site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\anaconda\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: joblib in c:\anaconda\lib\site-packages (from nltk->ekphrasis) (1.1.0)
# Requirement already satisfied: click in c:\anaconda\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\anaconda\lib\site-packages (from nltk->ekphrasis) (2022.3.15)

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")
def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai Proses pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Selamat dan sukses atas dilantiknya Bapak @hen...
# 1           1  Di sini Semarang, Di sana Malang. Di mana-mana...
# 2           2  🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3           3  🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 4           4          #SalingSupport 🎗️ https://t.co/HJesn2iFby
# 5           5  "Kami Arema, Salam Satu Jiwa" 🌟\n\nCuplikan vi...
# 6           6  Duka kita bersama, tapi percayalah harus bangk...
# 7           7  Laga PSIS Semarang vs Bhayangkara FC ditunda. ...
# 8           8  Keluarga besar PSIS Semarang turut berdukacita...
# 9           9  Persiapan matang selama 2 minggu jadi modal PS...
#
#                                               step01
# 0  selamat dan sukses atas dilantiknya bapak hend...
# 1  di sini semarang di sana malang di mana mana k...
# 2  informasi terkait tiket psis vs bhayangkara fc...
# 3                     team news cozhmhmgl cocwwkvrva
# 4                                        cohjesnifby
# 5  kami arema salam satu jiwa cuplikan video kami...
# 6  duka kita bersama tapi percayalah harus bangki...
# 7  laga psis semarang vs bhayangkara fc ditunda cogk
# 8  keluarga besar psis semarang turut berdukacita...
# 9  persiapan matang selama   minggu jadi modal ps...

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 3.2+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 4 to 183
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      int64
#  1   Tweets      7 non-null      object
#  2   step01      7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 168.0+ bytes

# %%
df_hapus.head(10)
# Out:
#      Unnamed: 0                                             Tweets  \
# 4             4          #SalingSupport 🎗️ https://t.co/HJesn2iFby
# 15           15   𝐇𝐞 𝐢𝐬 𝐛𝐚𝐜𝐤. 👁️🔵\n\n#PSIS https://t.co/8AzkHeumnX
# 50           50                                      @ForzaPSIS 😂😂
# 81           81  𝗨𝗡𝗟𝗘𝗔𝗦𝗛 𝗧𝗛𝗘 𝗠𝗔𝗫𝗜𝗠𝗨𝗠 𝗣𝗢𝗪𝗘𝗥‼️\n\n#PSISDAY https:...
# 95           95                                               😤😤😤😤
# 113         113                   #PSISDAY https://t.co/kFenfng0qE
# 183         183                          💙 https://t.co/cZgSTu4Wle
#
#           step01
# 4    cohjesnifby
# 15   coazkheumnx
# 50     forzapsis
# 81   copvrdvkfby
# 95
# 113  cokfenfngqe
# 183  coczgstuwle

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  193 non-null    float64
#  1   Tweets      193 non-null    object
#  2   step01      193 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 4.5+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0           0.0  Selamat dan sukses atas dilantiknya Bapak @hen...
# 1           1.0  Di sini Semarang, Di sana Malang. Di mana-mana...
# 2           2.0  🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3           3.0  🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 5           5.0  "Kami Arema, Salam Satu Jiwa" 🌟\n\nCuplikan vi...
# ..          ...                                                ...
# 195       195.0  GOLAZO FROM JONATHAN CANTILLANA ZORRILLAAAA!!!...
# 196       196.0                 Gol untuk Persik 1-1. \n\n#PSISDAY
# 197       197.0  '54 Krusial! Penyelamatan Redondo hentikan usa...
# 198       198.0  Pergantian pemain\n\nWawan masuk,\nHari Nur ke...
# 199       199.0  Kick-off babak kedua! Tambah atau pertahankan....
#
#                                                 step01
# 0    selamat dan sukses atas dilantiknya bapak hend...
# 1    di sini semarang di sana malang di mana mana k...
# 2    informasi terkait tiket psis vs bhayangkara fc...
# 3                       team news cozhmhmgl cocwwkvrva
# 5    kami arema salam satu jiwa cuplikan video kami...
# ..                                                 ...
# 195    golazo from jonathan cantillana zorrillaaaa
# 196                               gol untuk persik
# 197    krusial penyelamatan redondo hentikan usaha ...
# 198      pergantian pemain wawan masuk hari nur keluar
# 199  kick off babak kedua tambah atau pertahankan a...
#
# [193 rows x 3 columns]

# %% [markdown]
# ## Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#     Unnamed: 0                                             Tweets  \
# 0          0.0  Selamat dan sukses atas dilantiknya Bapak @hen...
# 1          1.0  Di sini Semarang, Di sana Malang. Di mana-mana...
# 2          2.0  🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3          3.0  🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 5          5.0  "Kami Arema, Salam Satu Jiwa" 🌟\n\nCuplikan vi...
# 6          6.0  Duka kita bersama, tapi percayalah harus bangk...
# 7          7.0  Laga PSIS Semarang vs Bhayangkara FC ditunda. ...
# 8          8.0  Keluarga besar PSIS Semarang turut berdukacita...
# 9          9.0  Persiapan matang selama 2 minggu jadi modal PS...
# 10        10.0  Perjuangan berlanjut!\n\nHadapi Bhayangkara FC...
#
#                                                step01  \
# 0   selamat dan sukses atas dilantiknya bapak hend...
# 1   di sini semarang di sana malang di mana mana k...
# 2   informasi terkait tiket psis vs bhayangkara fc...
# 3                      team news cozhmhmgl cocwwkvrva
# 5   kami arema salam satu jiwa cuplikan video kami...
# 6   duka kita bersama tapi percayalah harus bangki...
# 7   laga psis semarang vs bhayangkara fc ditunda cogk
# 8   keluarga besar psis semarang turut berdukacita...
# 9   persiapan matang selama   minggu jadi modal ps...
# 10  perjuangan berlanjut hadapi bhayangkara fc psi...
#
#                                                tokens
# 0   [selamat, dan, sukses, atas, dilantiknya, bapa...
# 1   [di, sini, semarang, di, sana, malang, di, man...
# 2   [informasi, terkait, tiket, psis, vs, bhayangk...
# 3                 [team, news, cozhmhmgl, cocwwkvrva]
# 5   [kami, arema, salam, satu, jiwa, cuplikan, vid...
# 6   [duka, kita, bersama, tapi, percayalah, harus,...
# 7   [laga, psis, semarang, vs, bhayangkara, fc, di...
# 8   [keluarga, besar, psis, semarang, turut, berdu...
# 9   [persiapan, matang, selama, minggu, jadi, moda...
# 10  [perjuangan, berlanjut, hadapi, bhayangkara, f...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#     Unnamed: 0                                             Tweets  \
# 0          0.0  Selamat dan sukses atas dilantiknya Bapak @hen...
# 1          1.0  Di sini Semarang, Di sana Malang. Di mana-mana...
# 2          2.0  🚨Informasi terkait tiket PSIS vs Bhayangkara F...
# 3          3.0  🔵 Team News\n\n📰 https://t.co/Z8hmhMglXZ\n\n#P...
# 5          5.0  "Kami Arema, Salam Satu Jiwa" 🌟\n\nCuplikan vi...
# 6          6.0  Duka kita bersama, tapi percayalah harus bangk...
# 7          7.0  Laga PSIS Semarang vs Bhayangkara FC ditunda. ...
# 8          8.0  Keluarga besar PSIS Semarang turut berdukacita...
# 9          9.0  Persiapan matang selama 2 minggu jadi modal PS...
# 10        10.0  Perjuangan berlanjut!\n\nHadapi Bhayangkara FC...
#
#                                                step01  \
# 0   selamat dan sukses atas dilantiknya bapak hend...
# 1   di sini semarang di sana malang di mana mana k...
# 2   informasi terkait tiket psis vs bhayangkara fc...
# 3                      team news cozhmhmgl cocwwkvrva
# 5   kami arema salam satu jiwa cuplikan video kami...
# 6   duka kita bersama tapi percayalah harus bangki...
# 7   laga psis semarang vs bhayangkara fc ditunda cogk
# 8   keluarga besar psis semarang turut berdukacita...
# 9   persiapan matang selama   minggu jadi modal ps...
# 10  perjuangan berlanjut hadapi bhayangkara fc psi...
#
#                                                tokens  \
# 0   [selamat, dan, sukses, atas, dilantiknya, bapa...
# 1   [di, sini, semarang, di, sana, malang, di, man...
# 2   [informasi, terkait, tiket, psis, vs, bhayangk...
# 3                 [team, news, cozhmhmgl, cocwwkvrva]
# 5   [kami, arema, salam, satu, jiwa, cuplikan, vid...
# 6   [duka, kita, bersama, tapi, percayalah, harus,...
# 7   [laga, psis, semarang, vs, bhayangkara, fc, di...
# 8   [keluarga, besar, psis, semarang, turut, berdu...
# 9   [persiapan, matang, selama, minggu, jadi, moda...
# 10  [perjuangan, berlanjut, hadapi, bhayangkara, f...
#
#                                          final_tokens  \
# 0   [selamat, dan, sukses, atas, dilantiknya, bapa...
# 1   [di, sini, semarang, di, sana, malang, di, man...
# 2   [informasi, terkait, tiket, psis, vs, bhayangk...
# 3                 [team, news, cozhmhmgl, cocwwkvrva]
# 5   [kami, arema, salam, satu, jiwa, cuplikan, vid...
# 6   [duka, kita, bersama, tapi, percayalah, harus,...
# 7   [laga, psis, semarang, vs, bhayangkara, fc, di...
# 8   [keluarga, besar, psis, semarang, turut, berdu...
# 9   [persiapan, matang, selama, minggu, jadi, moda...
# 10  [perjuangan, berlanjut, hadapi, bhayangkara, f...
#
#                                                step02
# 0   selamat dan sukses atas dilantiknya bapak hend...
# 1   di sini semarang di sana malang di mana mana k...
# 2   informasi terkait tiket psis vs bhayangkara fc...
# 3                      team news cozhmhmgl cocwwkvrva
# 5   kami arema salam satu jiwa cuplikan video kami...
# 6   duka kita bersama tapi percayalah harus bangki...
# 7   laga psis semarang vs bhayangkara fc ditunda cogk
# 8   keluarga besar psis semarang turut berdukacita...
# 9   persiapan matang selama minggu jadi modal psis...
# 10  perjuangan berlanjut hadapi bhayangkara fc psi...

# %% [markdown]
# ## Simpan Clean Dataset

# %%
df_new.to_csv('clean_dataset_psisfcofficial')
